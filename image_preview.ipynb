# %%
from IPython.display import Image, display, clear_output
import time

# %%
while True:
    display(Image(filename='/mnt/qb/work/geiger/pghosh58/transfuser/x.png'))
    time.sleep(1)
    clear_output(wait=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2056844/1116714992.py in <module>
#       1 while True:
#       2     display(Image(filename='/mnt/qb/work/geiger/pghosh58/transfuser/x.png'))
# ----> 3     time.sleep(1)
#       4     clear_output(wait=True)
#
# KeyboardInterrupt:
